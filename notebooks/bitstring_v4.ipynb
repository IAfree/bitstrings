# %% [markdown]
# ##### General steps performed:
# - Load bit strings from files
# - Create DataFrame with MultiIndex
# - Transform DataFrame to create string pairings for all files
# - Create DataFrame's with string comparison values
#
# ---
#
# ---

# %%
import os
import sys
from difflib import SequenceMatcher
import collections
import xml.etree.ElementTree as ET
#import itertools

#import json
#import requests

import numpy as np
import pandas as pd

from bitstring import Bits, BitArray, ConstBitStream, BitStream

import jellyfish as jf

#import matplotlib.pyplot as plt
#%matplotlib inline

#---------------------------------------------------------------------------------------
print ('python version: ', sys.version_info, '\n')
#---------------------------------------------------------------------------------------

# the following points to local directory due to size of files (didn't want to clog my Drive)...
print (os.getcwd())   # C:\Users\Reid\Google Drive\projects\bitstrings\media
os.chdir(os.path.join(os.path.expanduser('~'),'projects'))
print (os.getcwd())   # C:\Users\Reid\projects\bitstrings\media
print ()

#---------------------------------------------------------------------------------------

# set media_dir and create list of files in directory
media_dir = './bitstrings/media/'

file_name_list = [f for f in os.listdir(media_dir) if os.path.isfile(os.path.join(media_dir, f))]

#remove Thumbs.db
file_name_list.remove('Thumbs.db')
#---------------------------------------------------------------------------------------
file_bitarrays = {}
file_extensions = []
# Out:
# python version:  sys.version_info(major=3, minor=5, micro=2, releaselevel='final', serial=0)
#
# C:\Users\Reid\Google Drive\projects\bitstrings\notebooks
# C:\Users\Reid\projects

# %% [markdown]
# ---
# ##### Load bit strings from files

# %%
load_approach = 0
nbytes = 32*8 # 256 bits aka 32 bytes
if load_approach == 1:
    for file in file_name_list:
        file_name, file_ext = file.rsplit(sep='.', maxsplit=1)
        #print('', file_ext, ' | ', file_ext.lower())
        file_ext = file_ext.lower()
        if file_ext == 'jpeg':
            file_ext = 'jpg'
        file_extensions.append(file_ext.lower())
        if file_ext in file_bitarrays.keys():
            with open((media_dir+file), 'rb') as f:
                packet = ConstBitStream(bytes = f.read(nbytes), length = nbytes*8)
                while(packet.pos < nbytes*8):
                    byte = packet.read(8).uint
                    file_bitarrays[file_ext].append([file_name,chr(byte)])
        else:
            with open((media_dir+file), 'rb') as f:
                packet = ConstBitStream(bytes = f.read(nbytes), length = nbytes*8)
                while(packet.pos < nbytes*8):
                    byte = packet.read(8).uint
                    file_bitarrays[file_ext] = ([file_name,chr(byte)])
else:
    for file in file_name_list:
        file_name, file_ext = file.rsplit(sep='.', maxsplit=1)
        file_ext = file_ext.lower()
        if file_ext == 'jpeg':
            file_ext = 'jpg'
        file_extensions.append(file_ext.lower())
        if file_ext in file_bitarrays.keys():
            with open((media_dir+file), 'rb') as f:
                file_bitarrays[file_ext].append([file_name,BitArray(bytes=f.read(),length=nbytes)])
        else:
            with open((media_dir+file), 'rb') as f:
                file_bitarrays[file_ext] = ([[file_name,BitArray(bytes=f.read(),length=nbytes)]])

print ('Loaded first ', nbytes,' ',\
       'for ',len(file_extensions),' files ',\
       'from ',media_dir,' directory, ',\
       'representing ',len(file_bitarrays),' file types\n',sep='')

print ('File types and counts:')
print (pd.Series(np.array(file_extensions)).value_counts())
# Out:
# Loaded first 256 for 30 files from ./bitstrings/media/ directory, representing 15 file types
#
# File types and counts:
# jpg    3
# mov    2
# wmv    2
# mod    2
# pdf    2
# ino    2
# svg    2
# 3mf    2
# png    2
# mp4    2
# avi    2
# pak    2
# m4a    2
# nef    2
# 3gp    1
# dtype: int64

# %% [markdown]
# ---
# ##### Create DataFrame with MultiIndex

# %%
test_dict={}

for k, v in file_bitarrays.items():
    for key, value in v:
        test_dict.update({(key,k):str(value)})
        
df = pd.DataFrame.from_dict(test_dict,orient='index')

fe = []  # list for file extensions
fn = []  # list for file names
for x in range(len(df.index)):
    fe.append(df.index[x][1])
    fn.append(df.index[x][0])
array = [fe,fn]

tuples = list(zip(*array))
index = pd.MultiIndex.from_tuples(tuples, names=['file_type', 'file_name'])
df = pd.DataFrame(df[0].tolist(), index=index)
print (df.shape)
print ('Preview of df:')
df[:5]
# Out:
# (30, 1)
# Preview of df:
#                                                                         0
# file_type file_name
# svg       logo_64x64    0x3c3f786d6c2076657273696f6e3d22312e302220656e...
# jpg       SUNP0001      0xffd8ffe1187f45786966000049492a00080000000a00...
# mod       MOV065        0x000001ba4400040004010189c3f8000001bb001280c4...
# ino       Final_Sketch  0x2f2f2044485420636f64652066726f6d3a0a2f2f2045...
# avi       SUNP0002      0x5249464660045500415649204c495354ec7f00006864...

# %% [markdown]
# ---
# ##### Transform DataFrame to create string pairings for all files
# _consider transforming in place if memory is an issue_

# %%
dfx = pd.DataFrame([df[0].tolist()] * df.shape[0], index=df.index, columns=df.index)  # make columns for each file
dfx = dfx.applymap(lambda x: list([x]))  # make cell values into lists
dfp = dfx + dfx.T  # create string pairings for each row/column intersection
#dfp.mask(np.triu(np.ones(dfp.shape)).astype(bool))  # If desired, cut off upper triangle of df / array.

# %% [markdown]
# ---
# ##### Create DataFrame's with string comparison values
# - jf.levenshtein_distance [link](https://jellyfish.readthedocs.io/en/latest/comparison.html#levenshtein-distance) (other methods available)
# - SequenceMatcher [link](https://docs.python.org/3.5/library/difflib.html#difflib.SequenceMatcher.ratio)
#
# _*some models might require that comparison values are normalized or otherwise adjusted prior to modeling_

# %%
lev_distance_df = dfp.applymap(lambda x: jf.levenshtein_distance(x[0], x[1]))
print ('Preview of :')
lev_distance_df
# Out:
# Preview of :
# file_type                                             svg      jpg    mod  \
# file_name                                      logo_64x64 SUNP0001 MOV065
# file_type file_name
# svg       logo_64x64                                    0       56     58
# jpg       SUNP0001                                     56        0     48
# mod       MOV065                                       58       48      0
# ino       Final_Sketch                                 49       54     57
# avi       SUNP0002                                     51       49     48
# mod       MOV06C                                       58       48      0
# 3mf       Left Curve Track                             59       43     45
# jpg       WP_20150307_22_46_02_Pro                     53       38     46
# m4a       mss_v110_theme4                              51       49     51
# pdf       Webinar_Kelloggs-NCS_Handout_12-9-14         52       57     56
# m4a       Cosmic Book Club                             55       46     47
# png       fail7                                        60       40     45
# jpg       SUNP0180                                     57        3     48
# wmv       Lecture                                      60       39     51
# ino       FIKK4CTHOUFWXUF                              52       55     59
# 3mf       Tetrahedron Shape                            59       43     45
# nef       DSC_0009_009                                 61       36     41
# pak       package                                      57       60     56
# wmv       Uncharted Rough Cut                          56       43     52
# avi       SUNP0096                                     52       50     50
# mp4       download                                     56       51     48
# pdf       DoubleVerify_2H2010TrustIndexFinal           52       57     56
# mp4       Iguazu Falls d                               54       48     50
# svg       icon-exoticpets                               2       56     58
# png       mem7                                         61       40     47
# nef       DSC_1180                                     61       36     40
# 3gp       apt_scouting                                 55       52     48
# mov       Video                                        52       46     46
# pak       1                                            60       43     46
# mov       IMG_1153                                     53       45     45
#
# file_type                                               ino      avi    mod  \
# file_name                                      Final_Sketch SUNP0002 MOV06C
# file_type file_name
# svg       logo_64x64                                     49       51     58
# jpg       SUNP0001                                       54       49     48
# mod       MOV065                                         57       48      0
# ino       Final_Sketch                                    0       52     57
# avi       SUNP0002                                       52        0     48
# mod       MOV06C                                         57       48      0
# 3mf       Left Curve Track                               53       45     45
# jpg       WP_20150307_22_46_02_Pro                       52       49     46
# m4a       mss_v110_theme4                                49       49     51
# pdf       Webinar_Kelloggs-NCS_Handout_12-9-14           48       51     56
# m4a       Cosmic Book Club                               52       46     47
# png       fail7                                          55       50     45
# jpg       SUNP0180                                       54       49     48
# wmv       Lecture                                        56       55     51
# ino       FIKK4CTHOUFWXUF                                41       53     59
# 3mf       Tetrahedron Shape                              53       45     45
# nef       DSC_0009_009                                   58       48     41
# pak       package                                        56       56     56
# wmv       Uncharted Rough Cut                            54       55     52
# avi       SUNP0096                                       51        6     50
# mp4       download                                       51       53     48
# pdf       DoubleVerify_2H2010TrustIndexFinal             48       51     56
# mp4       Iguazu Falls d                                 50       55     50
# svg       icon-exoticpets                                48       51     58
# png       mem7                                           57       50     47
# nef       DSC_1180                                       58       48     40
# 3gp       apt_scouting                                   53       53     48
# mov       Video                                          51       50     46
# pak       1                                              58       51     46
# mov       IMG_1153                                       51       47     45
#
# file_type                                                   3mf  \
# file_name                                      Left Curve Track
# file_type file_name
# svg       logo_64x64                                         59
# jpg       SUNP0001                                           43
# mod       MOV065                                             45
# ino       Final_Sketch                                       53
# avi       SUNP0002                                           45
# mod       MOV06C                                             45
# 3mf       Left Curve Track                                    0
# jpg       WP_20150307_22_46_02_Pro                           49
# m4a       mss_v110_theme4                                    53
# pdf       Webinar_Kelloggs-NCS_Handout_12-9-14               54
# m4a       Cosmic Book Club                                   50
# png       fail7                                              33
# jpg       SUNP0180                                           43
# wmv       Lecture                                            45
# ino       FIKK4CTHOUFWXUF                                    56
# 3mf       Tetrahedron Shape                                   7
# nef       DSC_0009_009                                       32
# pak       package                                            55
# wmv       Uncharted Rough Cut                                45
# avi       SUNP0096                                           46
# mp4       download                                           53
# pdf       DoubleVerify_2H2010TrustIndexFinal                 54
# mp4       Iguazu Falls d                                     52
# svg       icon-exoticpets                                    59
# png       mem7                                               34
# nef       DSC_1180                                           32
# 3gp       apt_scouting                                       54
# mov       Video                                              48
# pak       1                                                  44
# mov       IMG_1153                                           49
#
# file_type                                                           jpg  \
# file_name                                      WP_20150307_22_46_02_Pro
# file_type file_name
# svg       logo_64x64                                                 53
# jpg       SUNP0001                                                   38
# mod       MOV065                                                     46
# ino       Final_Sketch                                               52
# avi       SUNP0002                                                   49
# mod       MOV06C                                                     46
# 3mf       Left Curve Track                                           49
# jpg       WP_20150307_22_46_02_Pro                                    0
# m4a       mss_v110_theme4                                            46
# pdf       Webinar_Kelloggs-NCS_Handout_12-9-14                       58
# m4a       Cosmic Book Club                                           44
# png       fail7                                                      46
# jpg       SUNP0180                                                   38
# wmv       Lecture                                                    49
# ino       FIKK4CTHOUFWXUF                                            54
# 3mf       Tetrahedron Shape                                          48
# nef       DSC_0009_009                                               41
# pak       package                                                    55
# wmv       Uncharted Rough Cut                                        51
# avi       SUNP0096                                                   48
# mp4       download                                                   50
# pdf       DoubleVerify_2H2010TrustIndexFinal                         58
# mp4       Iguazu Falls d                                             51
# svg       icon-exoticpets                                            53
# png       mem7                                                       47
# nef       DSC_1180                                                   41
# 3gp       apt_scouting                                               49
# mov       Video                                                      43
# pak       1                                                          46
# mov       IMG_1153                                                   44
#
# file_type                                                  m4a  \
# file_name                                      mss_v110_theme4
# file_type file_name
# svg       logo_64x64                                        51
# jpg       SUNP0001                                          49
# mod       MOV065                                            51
# ino       Final_Sketch                                      49
# avi       SUNP0002                                          49
# mod       MOV06C                                            51
# 3mf       Left Curve Track                                  53
# jpg       WP_20150307_22_46_02_Pro                          46
# m4a       mss_v110_theme4                                    0
# pdf       Webinar_Kelloggs-NCS_Handout_12-9-14              55
# m4a       Cosmic Book Club                                  26
# png       fail7                                             52
# jpg       SUNP0180                                          49
# wmv       Lecture                                           53
# ino       FIKK4CTHOUFWXUF                                   46
# 3mf       Tetrahedron Shape                                 51
# nef       DSC_0009_009                                      48
# pak       package                                           55
# wmv       Uncharted Rough Cut                               51
# avi       SUNP0096                                          49
# mp4       download                                          31
# pdf       DoubleVerify_2H2010TrustIndexFinal                55
# mp4       Iguazu Falls d                                    25
# svg       icon-exoticpets                                   51
# png       mem7                                              52
# nef       DSC_1180                                          48
# 3gp       apt_scouting                                      32
# mov       Video                                             37
# pak       1                                                 44
# mov       IMG_1153                                          34
#
# file_type                                                                       pdf  \
# file_name                                      Webinar_Kelloggs-NCS_Handout_12-9-14
# file_type file_name
# svg       logo_64x64                                                             52
# jpg       SUNP0001                                                               57
# mod       MOV065                                                                 56
# ino       Final_Sketch                                                           48
# avi       SUNP0002                                                               51
# mod       MOV06C                                                                 56
# 3mf       Left Curve Track                                                       54
# jpg       WP_20150307_22_46_02_Pro                                               58
# m4a       mss_v110_theme4                                                        55
# pdf       Webinar_Kelloggs-NCS_Handout_12-9-14                                    0
# m4a       Cosmic Book Club                                                       55
# png       fail7                                                                  48
# jpg       SUNP0180                                                               57
# wmv       Lecture                                                                56
# ino       FIKK4CTHOUFWXUF                                                        51
# 3mf       Tetrahedron Shape                                                      54
# nef       DSC_0009_009                                                           52
# pak       package                                                                59
# wmv       Uncharted Rough Cut                                                    56
# avi       SUNP0096                                                               53
# mp4       download                                                               54
# pdf       DoubleVerify_2H2010TrustIndexFinal                                      0
# mp4       Iguazu Falls d                                                         55
# svg       icon-exoticpets                                                        51
# png       mem7                                                                   48
# nef       DSC_1180                                                               53
# 3gp       apt_scouting                                                           58
# mov       Video                                                                  55
# pak       1                                                                      53
# mov       IMG_1153                                                               55
#
# file_type                                        ...         mp4  \
# file_name                                        ...    download
# file_type file_name                              ...
# svg       logo_64x64                             ...          56
# jpg       SUNP0001                               ...          51
# mod       MOV065                                 ...          48
# ino       Final_Sketch                           ...          51
# avi       SUNP0002                               ...          53
# mod       MOV06C                                 ...          48
# 3mf       Left Curve Track                       ...          53
# jpg       WP_20150307_22_46_02_Pro               ...          50
# m4a       mss_v110_theme4                        ...          31
# pdf       Webinar_Kelloggs-NCS_Handout_12-9-14   ...          54
# m4a       Cosmic Book Club                       ...          20
# png       fail7                                  ...          51
# jpg       SUNP0180                               ...          52
# wmv       Lecture                                ...          54
# ino       FIKK4CTHOUFWXUF                        ...          51
# 3mf       Tetrahedron Shape                      ...          53
# nef       DSC_0009_009                           ...          50
# pak       package                                ...          55
# wmv       Uncharted Rough Cut                    ...          54
# avi       SUNP0096                               ...          55
# mp4       download                               ...           0
# pdf       DoubleVerify_2H2010TrustIndexFinal     ...          54
# mp4       Iguazu Falls d                         ...          32
# svg       icon-exoticpets                        ...          55
# png       mem7                                   ...          50
# nef       DSC_1180                               ...          50
# 3gp       apt_scouting                           ...          35
# mov       Video                                  ...          35
# pak       1                                      ...          44
# mov       IMG_1153                               ...          35
#
# file_type                                                                     pdf  \
# file_name                                      DoubleVerify_2H2010TrustIndexFinal
# file_type file_name
# svg       logo_64x64                                                           52
# jpg       SUNP0001                                                             57
# mod       MOV065                                                               56
# ino       Final_Sketch                                                         48
# avi       SUNP0002                                                             51
# mod       MOV06C                                                               56
# 3mf       Left Curve Track                                                     54
# jpg       WP_20150307_22_46_02_Pro                                             58
# m4a       mss_v110_theme4                                                      55
# pdf       Webinar_Kelloggs-NCS_Handout_12-9-14                                  0
# m4a       Cosmic Book Club                                                     55
# png       fail7                                                                48
# jpg       SUNP0180                                                             57
# wmv       Lecture                                                              56
# ino       FIKK4CTHOUFWXUF                                                      51
# 3mf       Tetrahedron Shape                                                    54
# nef       DSC_0009_009                                                         52
# pak       package                                                              59
# wmv       Uncharted Rough Cut                                                  56
# avi       SUNP0096                                                             53
# mp4       download                                                             54
# pdf       DoubleVerify_2H2010TrustIndexFinal                                    0
# mp4       Iguazu Falls d                                                       55
# svg       icon-exoticpets                                                      51
# png       mem7                                                                 48
# nef       DSC_1180                                                             53
# 3gp       apt_scouting                                                         58
# mov       Video                                                                55
# pak       1                                                                    53
# mov       IMG_1153                                                             55
#
# file_type                                                 mp4             svg  \
# file_name                                      Iguazu Falls d icon-exoticpets
# file_type file_name
# svg       logo_64x64                                       54               2
# jpg       SUNP0001                                         48              56
# mod       MOV065                                           50              58
# ino       Final_Sketch                                     50              48
# avi       SUNP0002                                         55              51
# mod       MOV06C                                           50              58
# 3mf       Left Curve Track                                 52              59
# jpg       WP_20150307_22_46_02_Pro                         51              53
# m4a       mss_v110_theme4                                  25              51
# pdf       Webinar_Kelloggs-NCS_Handout_12-9-14             55              51
# m4a       Cosmic Book Club                                 31              55
# png       fail7                                            50              60
# jpg       SUNP0180                                         48              57
# wmv       Lecture                                          53              60
# ino       FIKK4CTHOUFWXUF                                  49              50
# 3mf       Tetrahedron Shape                                52              59
# nef       DSC_0009_009                                     48              61
# pak       package                                          57              57
# wmv       Uncharted Rough Cut                              53              56
# avi       SUNP0096                                         55              52
# mp4       download                                         32              55
# pdf       DoubleVerify_2H2010TrustIndexFinal               55              51
# mp4       Iguazu Falls d                                    0              53
# svg       icon-exoticpets                                  53               0
# png       mem7                                             51              61
# nef       DSC_1180                                         47              61
# 3gp       apt_scouting                                     32              55
# mov       Video                                            37              53
# pak       1                                                45              60
# mov       IMG_1153                                         36              53
#
# file_type                                       png      nef          3gp  \
# file_name                                      mem7 DSC_1180 apt_scouting
# file_type file_name
# svg       logo_64x64                             61       61           55
# jpg       SUNP0001                               40       36           52
# mod       MOV065                                 47       40           48
# ino       Final_Sketch                           57       58           53
# avi       SUNP0002                               50       48           53
# mod       MOV06C                                 47       40           48
# 3mf       Left Curve Track                       34       32           54
# jpg       WP_20150307_22_46_02_Pro               47       41           49
# m4a       mss_v110_theme4                        52       48           32
# pdf       Webinar_Kelloggs-NCS_Handout_12-9-14   48       53           58
# m4a       Cosmic Book Club                       45       44           31
# png       fail7                                  10       35           50
# jpg       SUNP0180                               40       36           52
# wmv       Lecture                                41       38           55
# ino       FIKK4CTHOUFWXUF                        56       56           51
# 3mf       Tetrahedron Shape                      35       34           54
# nef       DSC_0009_009                           36        1           49
# pak       package                                60       59           56
# wmv       Uncharted Rough Cut                    42       39           52
# avi       SUNP0096                               49       49           54
# mp4       download                               50       50           35
# pdf       DoubleVerify_2H2010TrustIndexFinal     48       53           58
# mp4       Iguazu Falls d                         51       47           32
# svg       icon-exoticpets                        61       61           55
# png       mem7                                    0       36           52
# nef       DSC_1180                               36        0           48
# 3gp       apt_scouting                           52       48            0
# mov       Video                                  43       43           36
# pak       1                                      43       39           45
# mov       IMG_1153                               41       40           36
#
# file_type                                        mov pak      mov
# file_name                                      Video   1 IMG_1153
# file_type file_name
# svg       logo_64x64                              52  60       53
# jpg       SUNP0001                                46  43       45
# mod       MOV065                                  46  46       45
# ino       Final_Sketch                            51  58       51
# avi       SUNP0002                                50  51       47
# mod       MOV06C                                  46  46       45
# 3mf       Left Curve Track                        48  44       49
# jpg       WP_20150307_22_46_02_Pro                43  46       44
# m4a       mss_v110_theme4                         37  44       34
# pdf       Webinar_Kelloggs-NCS_Handout_12-9-14    55  53       55
# m4a       Cosmic Book Club                        30  42       27
# png       fail7                                   41  42       41
# jpg       SUNP0180                                46  43       45
# wmv       Lecture                                 48  43       47
# ino       FIKK4CTHOUFWXUF                         51  57       51
# 3mf       Tetrahedron Shape                       49  44       49
# nef       DSC_0009_009                            43  39       40
# pak       package                                 60  60       60
# wmv       Uncharted Rough Cut                     48  43       50
# avi       SUNP0096                                52  51       49
# mp4       download                                35  44       35
# pdf       DoubleVerify_2H2010TrustIndexFinal      55  53       55
# mp4       Iguazu Falls d                          37  45       36
# svg       icon-exoticpets                         53  60       53
# png       mem7                                    43  43       41
# nef       DSC_1180                                43  39       40
# 3gp       apt_scouting                            36  45       36
# mov       Video                                    0  42        6
# pak       1                                       42   0       39
# mov       IMG_1153                                 6  39        0
#
# [30 rows x 30 columns]

# %%
seq_match_df = dfp.applymap(lambda x: SequenceMatcher(None, x[0], x[1]).ratio())
print ('Preview of :')
seq_match_df
# Out:
# Preview of :
# file_type                                             svg       jpg       mod  \
# file_name                                      logo_64x64  SUNP0001    MOV065
# file_type file_name
# svg       logo_64x64                             1.000000  0.242424  0.196970
# jpg       SUNP0001                               0.181818  1.000000  0.393939
# mod       MOV065                                 0.151515  0.393939  1.000000
# ino       Final_Sketch                           0.333333  0.257576  0.196970
# avi       SUNP0002                               0.257576  0.363636  0.242424
# mod       MOV06C                                 0.151515  0.393939  1.000000
# 3mf       Left Curve Track                       0.212121  0.393939  0.363636
# jpg       WP_20150307_22_46_02_Pro               0.181818  0.393939  0.212121
# m4a       mss_v110_theme4                        0.303030  0.303030  0.424242
# pdf       Webinar_Kelloggs-NCS_Handout_12-9-14   0.333333  0.287879  0.227273
# m4a       Cosmic Book Club                       0.242424  0.469697  0.393939
# png       fail7                                  0.151515  0.454545  0.363636
# jpg       SUNP0180                               0.181818  0.969697  0.393939
# wmv       Lecture                                0.166667  0.439394  0.166667
# ino       FIKK4CTHOUFWXUF                        0.257576  0.242424  0.181818
# 3mf       Tetrahedron Shape                      0.242424  0.378788  0.348485
# nef       DSC_0009_009                           0.151515  0.439394  0.484848
# pak       package                                0.242424  0.212121  0.257576
# wmv       Uncharted Rough Cut                    0.166667  0.363636  0.151515
# avi       SUNP0096                               0.257576  0.287879  0.242424
# mp4       download                               0.227273  0.318182  0.378788
# pdf       DoubleVerify_2H2010TrustIndexFinal     0.333333  0.287879  0.227273
# mp4       Iguazu Falls d                         0.257576  0.257576  0.378788
# svg       icon-exoticpets                        0.969697  0.242424  0.196970
# png       mem7                                   0.166667  0.439394  0.378788
# nef       DSC_1180                               0.151515  0.469697  0.469697
# 3gp       apt_scouting                           0.227273  0.303030  0.363636
# mov       Video                                  0.227273  0.500000  0.378788
# pak       1                                      0.212121  0.393939  0.439394
# mov       IMG_1153                               0.242424  0.500000  0.378788
#
# file_type                                               ino       avi  \
# file_name                                      Final_Sketch  SUNP0002
# file_type file_name
# svg       logo_64x64                               0.318182  0.196970
# jpg       SUNP0001                                 0.272727  0.363636
# mod       MOV065                                   0.090909  0.242424
# ino       Final_Sketch                             1.000000  0.333333
# avi       SUNP0002                                 0.318182  1.000000
# mod       MOV06C                                   0.090909  0.242424
# 3mf       Left Curve Track                         0.257576  0.242424
# jpg       WP_20150307_22_46_02_Pro                 0.333333  0.257576
# m4a       mss_v110_theme4                          0.378788  0.121212
# pdf       Webinar_Kelloggs-NCS_Handout_12-9-14     0.363636  0.242424
# m4a       Cosmic Book Club                         0.257576  0.121212
# png       fail7                                    0.287879  0.227273
# jpg       SUNP0180                                 0.242424  0.363636
# wmv       Lecture                                  0.106061  0.303030
# ino       FIKK4CTHOUFWXUF                          0.484848  0.181818
# 3mf       Tetrahedron Shape                        0.090909  0.242424
# nef       DSC_0009_009                             0.212121  0.196970
# pak       package                                  0.106061  0.257576
# wmv       Uncharted Rough Cut                      0.227273  0.333333
# avi       SUNP0096                                 0.318182  0.924242
# mp4       download                                 0.212121  0.121212
# pdf       DoubleVerify_2H2010TrustIndexFinal       0.363636  0.242424
# mp4       Iguazu Falls d                           0.378788  0.121212
# svg       icon-exoticpets                          0.348485  0.166667
# png       mem7                                     0.287879  0.227273
# nef       DSC_1180                                 0.212121  0.196970
# 3gp       apt_scouting                             0.303030  0.121212
# mov       Video                                    0.272727  0.121212
# pak       1                                        0.227273  0.121212
# mov       IMG_1153                                 0.272727  0.121212
#
# file_type                                            mod              3mf  \
# file_name                                         MOV06C Left Curve Track
# file_type file_name
# svg       logo_64x64                            0.196970         0.181818
# jpg       SUNP0001                              0.393939         0.409091
# mod       MOV065                                1.000000         0.424242
# ino       Final_Sketch                          0.196970         0.257576
# avi       SUNP0002                              0.242424         0.242424
# mod       MOV06C                                1.000000         0.424242
# 3mf       Left Curve Track                      0.363636         1.000000
# jpg       WP_20150307_22_46_02_Pro              0.212121         0.348485
# m4a       mss_v110_theme4                       0.424242         0.242424
# pdf       Webinar_Kelloggs-NCS_Handout_12-9-14  0.227273         0.212121
# m4a       Cosmic Book Club                      0.393939         0.227273
# png       fail7                                 0.363636         0.560606
# jpg       SUNP0180                              0.393939         0.409091
# wmv       Lecture                               0.166667         0.409091
# ino       FIKK4CTHOUFWXUF                       0.181818         0.212121
# 3mf       Tetrahedron Shape                     0.348485         0.924242
# nef       DSC_0009_009                          0.484848         0.530303
# pak       package                               0.257576         0.227273
# wmv       Uncharted Rough Cut                   0.151515         0.363636
# avi       SUNP0096                              0.242424         0.196970
# mp4       download                              0.378788         0.393939
# pdf       DoubleVerify_2H2010TrustIndexFinal    0.227273         0.212121
# mp4       Iguazu Falls d                        0.378788         0.393939
# svg       icon-exoticpets                       0.196970         0.181818
# png       mem7                                  0.378788         0.545455
# nef       DSC_1180                              0.469697         0.530303
# 3gp       apt_scouting                          0.363636         0.287879
# mov       Video                                 0.378788         0.287879
# pak       1                                     0.439394         0.409091
# mov       IMG_1153                              0.378788         0.318182
#
# file_type                                                           jpg  \
# file_name                                      WP_20150307_22_46_02_Pro
# file_type file_name
# svg       logo_64x64                                           0.303030
# jpg       SUNP0001                                             0.393939
# mod       MOV065                                               0.318182
# ino       Final_Sketch                                         0.318182
# avi       SUNP0002                                             0.242424
# mod       MOV06C                                               0.318182
# 3mf       Left Curve Track                                     0.348485
# jpg       WP_20150307_22_46_02_Pro                             1.000000
# m4a       mss_v110_theme4                                      0.348485
# pdf       Webinar_Kelloggs-NCS_Handout_12-9-14                 0.303030
# m4a       Cosmic Book Club                                     0.348485
# png       fail7                                                0.409091
# jpg       SUNP0180                                             0.393939
# wmv       Lecture                                              0.333333
# ino       FIKK4CTHOUFWXUF                                      0.272727
# 3mf       Tetrahedron Shape                                    0.424242
# nef       DSC_0009_009                                         0.454545
# pak       package                                              0.242424
# wmv       Uncharted Rough Cut                                  0.318182
# avi       SUNP0096                                             0.242424
# mp4       download                                             0.348485
# pdf       DoubleVerify_2H2010TrustIndexFinal                   0.303030
# mp4       Iguazu Falls d                                       0.348485
# svg       icon-exoticpets                                      0.303030
# png       mem7                                                 0.393939
# nef       DSC_1180                                             0.454545
# 3gp       apt_scouting                                         0.333333
# mov       Video                                                0.318182
# pak       1                                                    0.303030
# mov       IMG_1153                                             0.318182
#
# file_type                                                  m4a  \
# file_name                                      mss_v110_theme4
# file_type file_name
# svg       logo_64x64                                  0.318182
# jpg       SUNP0001                                    0.303030
# mod       MOV065                                      0.424242
# ino       Final_Sketch                                0.363636
# avi       SUNP0002                                    0.121212
# mod       MOV06C                                      0.424242
# 3mf       Left Curve Track                            0.242424
# jpg       WP_20150307_22_46_02_Pro                    0.303030
# m4a       mss_v110_theme4                             1.000000
# pdf       Webinar_Kelloggs-NCS_Handout_12-9-14        0.212121
# m4a       Cosmic Book Club                            0.515152
# png       fail7                                       0.257576
# jpg       SUNP0180                                    0.303030
# wmv       Lecture                                     0.212121
# ino       FIKK4CTHOUFWXUF                             0.303030
# 3mf       Tetrahedron Shape                           0.242424
# nef       DSC_0009_009                                0.378788
# pak       package                                     0.196970
# wmv       Uncharted Rough Cut                         0.242424
# avi       SUNP0096                                    0.121212
# mp4       download                                    0.363636
# pdf       DoubleVerify_2H2010TrustIndexFinal          0.212121
# mp4       Iguazu Falls d                              0.727273
# svg       icon-exoticpets                             0.333333
# png       mem7                                        0.257576
# nef       DSC_1180                                    0.378788
# 3gp       apt_scouting                                0.621212
# mov       Video                                       0.515152
# pak       1                                           0.363636
# mov       IMG_1153                                    0.515152
#
# file_type                                                                       pdf  \
# file_name                                      Webinar_Kelloggs-NCS_Handout_12-9-14
# file_type file_name
# svg       logo_64x64                                                       0.348485
# jpg       SUNP0001                                                         0.257576
# mod       MOV065                                                           0.242424
# ino       Final_Sketch                                                     0.318182
# avi       SUNP0002                                                         0.333333
# mod       MOV06C                                                           0.242424
# 3mf       Left Curve Track                                                 0.227273
# jpg       WP_20150307_22_46_02_Pro                                         0.212121
# m4a       mss_v110_theme4                                                  0.151515
# pdf       Webinar_Kelloggs-NCS_Handout_12-9-14                             1.000000
# m4a       Cosmic Book Club                                                 0.151515
# png       fail7                                                            0.287879
# jpg       SUNP0180                                                         0.257576
# wmv       Lecture                                                          0.287879
# ino       FIKK4CTHOUFWXUF                                                  0.363636
# 3mf       Tetrahedron Shape                                                0.227273
# nef       DSC_0009_009                                                     0.166667
# pak       package                                                          0.121212
# wmv       Uncharted Rough Cut                                              0.166667
# avi       SUNP0096                                                         0.318182
# mp4       download                                                         0.257576
# pdf       DoubleVerify_2H2010TrustIndexFinal                               1.000000
# mp4       Iguazu Falls d                                                   0.151515
# svg       icon-exoticpets                                                  0.348485
# png       mem7                                                             0.303030
# nef       DSC_1180                                                         0.166667
# 3gp       apt_scouting                                                     0.151515
# mov       Video                                                            0.166667
# pak       1                                                                0.227273
# mov       IMG_1153                                                         0.166667
#
# file_type                                         ...          mp4  \
# file_name                                         ...     download
# file_type file_name                               ...
# svg       logo_64x64                              ...     0.227273
# jpg       SUNP0001                                ...     0.348485
# mod       MOV065                                  ...     0.318182
# ino       Final_Sketch                            ...     0.363636
# avi       SUNP0002                                ...     0.121212
# mod       MOV06C                                  ...     0.318182
# 3mf       Left Curve Track                        ...     0.378788
# jpg       WP_20150307_22_46_02_Pro                ...     0.363636
# m4a       mss_v110_theme4                         ...     0.363636
# pdf       Webinar_Kelloggs-NCS_Handout_12-9-14    ...     0.257576
# m4a       Cosmic Book Club                        ...     0.818182
# png       fail7                                   ...     0.181818
# jpg       SUNP0180                                ...     0.348485
# wmv       Lecture                                 ...     0.363636
# ino       FIKK4CTHOUFWXUF                         ...     0.318182
# 3mf       Tetrahedron Shape                       ...     0.287879
# nef       DSC_0009_009                            ...     0.363636
# pak       package                                 ...     0.181818
# wmv       Uncharted Rough Cut                     ...     0.272727
# avi       SUNP0096                                ...     0.121212
# mp4       download                                ...     1.000000
# pdf       DoubleVerify_2H2010TrustIndexFinal      ...     0.257576
# mp4       Iguazu Falls d                          ...     0.560606
# svg       icon-exoticpets                         ...     0.227273
# png       mem7                                    ...     0.409091
# nef       DSC_1180                                ...     0.378788
# 3gp       apt_scouting                            ...     0.575758
# mov       Video                                   ...     0.575758
# pak       1                                       ...     0.378788
# mov       IMG_1153                                ...     0.575758
#
# file_type                                                                     pdf  \
# file_name                                      DoubleVerify_2H2010TrustIndexFinal
# file_type file_name
# svg       logo_64x64                                                     0.348485
# jpg       SUNP0001                                                       0.257576
# mod       MOV065                                                         0.242424
# ino       Final_Sketch                                                   0.318182
# avi       SUNP0002                                                       0.333333
# mod       MOV06C                                                         0.242424
# 3mf       Left Curve Track                                               0.227273
# jpg       WP_20150307_22_46_02_Pro                                       0.212121
# m4a       mss_v110_theme4                                                0.151515
# pdf       Webinar_Kelloggs-NCS_Handout_12-9-14                           1.000000
# m4a       Cosmic Book Club                                               0.151515
# png       fail7                                                          0.287879
# jpg       SUNP0180                                                       0.257576
# wmv       Lecture                                                        0.287879
# ino       FIKK4CTHOUFWXUF                                                0.363636
# 3mf       Tetrahedron Shape                                              0.227273
# nef       DSC_0009_009                                                   0.166667
# pak       package                                                        0.121212
# wmv       Uncharted Rough Cut                                            0.166667
# avi       SUNP0096                                                       0.318182
# mp4       download                                                       0.257576
# pdf       DoubleVerify_2H2010TrustIndexFinal                             1.000000
# mp4       Iguazu Falls d                                                 0.151515
# svg       icon-exoticpets                                                0.348485
# png       mem7                                                           0.303030
# nef       DSC_1180                                                       0.166667
# 3gp       apt_scouting                                                   0.151515
# mov       Video                                                          0.166667
# pak       1                                                              0.227273
# mov       IMG_1153                                                       0.166667
#
# file_type                                                 mp4             svg  \
# file_name                                      Iguazu Falls d icon-exoticpets
# file_type file_name
# svg       logo_64x64                                 0.272727        0.969697
# jpg       SUNP0001                                   0.257576        0.181818
# mod       MOV065                                     0.303030        0.151515
# ino       Final_Sketch                               0.363636        0.363636
# avi       SUNP0002                                   0.121212        0.257576
# mod       MOV06C                                     0.303030        0.151515
# 3mf       Left Curve Track                           0.409091        0.212121
# jpg       WP_20150307_22_46_02_Pro                   0.348485        0.181818
# m4a       mss_v110_theme4                            0.681818        0.318182
# pdf       Webinar_Kelloggs-NCS_Handout_12-9-14       0.227273        0.303030
# m4a       Cosmic Book Club                           0.484848        0.242424
# png       fail7                                      0.333333        0.151515
# jpg       SUNP0180                                   0.257576        0.181818
# wmv       Lecture                                    0.212121        0.166667
# ino       FIKK4CTHOUFWXUF                            0.393939        0.257576
# 3mf       Tetrahedron Shape                          0.409091        0.242424
# nef       DSC_0009_009                               0.333333        0.151515
# pak       package                                    0.181818        0.287879
# wmv       Uncharted Rough Cut                        0.181818        0.136364
# avi       SUNP0096                                   0.121212        0.257576
# mp4       download                                   0.363636        0.227273
# pdf       DoubleVerify_2H2010TrustIndexFinal         0.227273        0.303030
# mp4       Iguazu Falls d                             1.000000        0.272727
# svg       icon-exoticpets                            0.287879        1.000000
# png       mem7                                       0.439394        0.166667
# nef       DSC_1180                                   0.333333        0.151515
# 3gp       apt_scouting                               0.621212        0.227273
# mov       Video                                      0.484848        0.227273
# pak       1                                          0.333333        0.212121
# mov       IMG_1153                                   0.484848        0.242424
#
# file_type                                            png       nef  \
# file_name                                           mem7  DSC_1180
# file_type file_name
# svg       logo_64x64                            0.242424  0.151515
# jpg       SUNP0001                              0.439394  0.454545
# mod       MOV065                                0.393939  0.469697
# ino       Final_Sketch                          0.242424  0.181818
# avi       SUNP0002                              0.227273  0.196970
# mod       MOV06C                                0.393939  0.469697
# 3mf       Left Curve Track                      0.530303  0.560606
# jpg       WP_20150307_22_46_02_Pro              0.409091  0.454545
# m4a       mss_v110_theme4                       0.257576  0.227273
# pdf       Webinar_Kelloggs-NCS_Handout_12-9-14  0.318182  0.181818
# m4a       Cosmic Book Club                      0.454545  0.257576
# png       fail7                                 0.878788  0.500000
# jpg       SUNP0180                              0.454545  0.454545
# wmv       Lecture                               0.439394  0.454545
# ino       FIKK4CTHOUFWXUF                       0.212121  0.121212
# 3mf       Tetrahedron Shape                     0.545455  0.545455
# nef       DSC_0009_009                          0.530303  0.984848
# pak       package                               0.151515  0.090909
# wmv       Uncharted Rough Cut                   0.363636  0.378788
# avi       SUNP0096                              0.227273  0.196970
# mp4       download                              0.409091  0.363636
# pdf       DoubleVerify_2H2010TrustIndexFinal    0.318182  0.181818
# mp4       Iguazu Falls d                        0.424242  0.333333
# svg       icon-exoticpets                       0.242424  0.151515
# png       mem7                                  1.000000  0.545455
# nef       DSC_1180                              0.530303  1.000000
# 3gp       apt_scouting                          0.363636  0.333333
# mov       Video                                 0.439394  0.257576
# pak       1                                     0.348485  0.378788
# mov       IMG_1153                              0.409091  0.303030
#
# file_type                                               3gp       mov  \
# file_name                                      apt_scouting     Video
# file_type file_name
# svg       logo_64x64                               0.227273  0.212121
# jpg       SUNP0001                                 0.303030  0.500000
# mod       MOV065                                   0.378788  0.363636
# ino       Final_Sketch                             0.242424  0.272727
# avi       SUNP0002                                 0.121212  0.121212
# mod       MOV06C                                   0.378788  0.363636
# 3mf       Left Curve Track                         0.378788  0.333333
# jpg       WP_20150307_22_46_02_Pro                 0.348485  0.333333
# m4a       mss_v110_theme4                          0.621212  0.530303
# pdf       Webinar_Kelloggs-NCS_Handout_12-9-14     0.212121  0.166667
# m4a       Cosmic Book Club                         0.636364  0.606061
# png       fail7                                    0.439394  0.454545
# jpg       SUNP0180                                 0.303030  0.500000
# wmv       Lecture                                  0.196970  0.469697
# ino       FIKK4CTHOUFWXUF                          0.196970  0.348485
# 3mf       Tetrahedron Shape                        0.363636  0.333333
# nef       DSC_0009_009                             0.333333  0.257576
# pak       package                                  0.227273  0.166667
# wmv       Uncharted Rough Cut                      0.151515  0.409091
# avi       SUNP0096                                 0.121212  0.121212
# mp4       download                                 0.575758  0.575758
# pdf       DoubleVerify_2H2010TrustIndexFinal       0.212121  0.166667
# mp4       Iguazu Falls d                           0.621212  0.409091
# svg       icon-exoticpets                          0.227273  0.196970
# png       mem7                                     0.393939  0.439394
# nef       DSC_1180                                 0.333333  0.257576
# 3gp       apt_scouting                             1.000000  0.469697
# mov       Video                                    0.515152  1.000000
# pak       1                                        0.363636  0.363636
# mov       IMG_1153                                 0.500000  0.924242
#
# file_type                                            pak       mov
# file_name                                              1  IMG_1153
# file_type file_name
# svg       logo_64x64                            0.151515  0.196970
# jpg       SUNP0001                              0.348485  0.500000
# mod       MOV065                                0.424242  0.363636
# ino       Final_Sketch                          0.181818  0.287879
# avi       SUNP0002                              0.121212  0.121212
# mod       MOV06C                                0.424242  0.363636
# 3mf       Left Curve Track                      0.393939  0.348485
# jpg       WP_20150307_22_46_02_Pro              0.303030  0.333333
# m4a       mss_v110_theme4                       0.333333  0.530303
# pdf       Webinar_Kelloggs-NCS_Handout_12-9-14  0.272727  0.166667
# m4a       Cosmic Book Club                      0.454545  0.606061
# png       fail7                                 0.454545  0.454545
# jpg       SUNP0180                              0.348485  0.500000
# wmv       Lecture                               0.363636  0.469697
# ino       FIKK4CTHOUFWXUF                       0.227273  0.348485
# 3mf       Tetrahedron Shape                     0.363636  0.348485
# nef       DSC_0009_009                          0.424242  0.287879
# pak       package                               0.227273  0.166667
# wmv       Uncharted Rough Cut                   0.287879  0.393939
# avi       SUNP0096                              0.121212  0.121212
# mp4       download                              0.363636  0.575758
# pdf       DoubleVerify_2H2010TrustIndexFinal    0.272727  0.166667
# mp4       Iguazu Falls d                        0.318182  0.409091
# svg       icon-exoticpets                       0.151515  0.196970
# png       mem7                                  0.393939  0.424242
# nef       DSC_1180                              0.439394  0.303030
# 3gp       apt_scouting                          0.318182  0.469697
# mov       Video                                 0.333333  0.924242
# pak       1                                     1.000000  0.363636
# mov       IMG_1153                              0.333333  1.000000
#
# [30 rows x 30 columns]

# %% [markdown]
# ---
# ### Next steps:  refine similarity matrices, perform clustering...
#
# - scipy.cluster [link](https://docs.scipy.org/doc/scipy/reference/cluster.html) (scipy.cluster.hierarchy in particular)
# - scikit-learn [link](http://scikit-learn.org/stable/modules/clustering.html#clustering)
# - NLTK [link](http://www.nltk.org/py-modindex.html) might not apply here but worth documenting [found this post particularly illuminating](https://nbviewer.jupyter.org/github/brandomr/document_cluster/blob/master/cluster_analysis_web.ipynb)
#
#
# ---
# Other References:
# - Carnegie Mellon Statistical Machine Learning course [page](http://www.stat.cmu.edu/~larry/=sml/) | [notes](http://www.stat.cmu.edu/~larry/=sml/clustering.pdf)
# - Kept coming across [ELKI](https://github.com/elki-project/elki) but only in Java
